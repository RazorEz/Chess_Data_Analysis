# %% [markdown]
# <h1><b>Project Aim:</b></h1>
#
# Predict winner of Chess Game

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("data/games.csv")

# %% [markdown]
# Data Snapshot

# %%
df.sample(1)
# Out:
#             id  rated    created_at  last_move_at  turns victory_status  \
# 1229  mm2yP7Ee   True  1.495670e+12  1.495670e+12     64         resign
#
#      winner increment_code  white_id  white_rating black_id  black_rating  \
# 1229  black           10+0  jesteroz          1282  mikavds          1285
#
#                                                   moves opening_eco  \
# 1229  e4 d6 d4 e6 Nf3 Nf6 Nc3 d5 e5 Ng8 Bg5 f6 Bf4 g...         C00
#
#                            opening_name  opening_ply
# 1229  Rat Defense: Small Center Defense            4

# %% [markdown]
# Quick Analysis of Data

# %%
print(f"Shape: {df.shape}")
print(f"Cols: {df.columns}")
print(f"Unique Increment Types: {df.increment_code.nunique()}")
print(df.dtypes)
# Out:
# Shape: (20058, 16)
# Cols: Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')
# Unique Increment Types: 400
# id                 object
# rated                bool
# created_at        float64
# last_move_at      float64
# turns               int64
# victory_status     object
# winner             object
# increment_code     object
# white_id           object
# white_rating        int64
# black_id           object
# black_rating        int64
# moves              object
# opening_eco        object
# opening_name       object
# opening_ply         int64
# dtype: object

# %% [markdown]
# <h2>In-Depth Data Analysis</h2>

# %%
# Graphs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hm/1bbcjtbd5c7__8ylm03tgs940000gn/T/ipykernel_1090/3829921810.py in <module>
#       1 #Plotting Win Percentage
# ----> 2 sns.barplot(x='winner', y='id', data=df)
#       3 #df.groupby('winner').agg({'id': ['count']}).reset_index(level=0))
#
# /opt/homebrew/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/homebrew/lib/python3.9/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...
